# %% [markdown]
# # Limpieza de Datos

# %%
import pandas as pd
import numpy as np

# %%
# Cargamos el data set
data = pd.read_csv(filepath_or_buffer='datasets/Data_unido_2018_2021.csv')
data.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13664\3643348335.py:2: DtypeWarning: Columns (13,28,29,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath_or_buffer='datasets/Data_unido_2018_2021.csv')
#     año    mes fecha_ingreso referida estado_civil  edad  \
# 0  2016  ABRIL    2016-04-01      NaN      SOLTERA    24
# 1  2016  ABRIL    2016-04-01      NaN      SOLTERA    30
# 2  2016  ABRIL    2016-04-01      NaN       CASADA    38
# 3  2016  ABRIL    2016-04-01      NaN      SOLTERA    23
# 4  2016  ABRIL    2016-04-01      NaN      SOLTERA    18
#
#   institucion_derechohab                         nivel_edu  \
# 0                NINGUNO                      PREPARATORIA
# 1                NINGUNO                        SECUNDARIA
# 2                NINGUNO  SIN ACCESO A LA EDUCACION FORMAL
# 3                NINGUNO                      PREPARATORIA
# 4                NINGUNO                        SECUNDARIA
#
# ...

# %%
data['resultado_ile'].value_counts()
# Out:
# COMPLETA    21877
# OTRO          491
# Name: resultado_ile, dtype: int64

# %% [markdown]
# Empezamos analizando la columna de referida

# %%
print('porcentaje de nulos:\n', (data.isnull().sum()*100) / len(data))
# Out:
# porcentaje de nulos:
#  año                           0.000000
# mes                           0.000000
# fecha_ingreso                 0.000000
# referida                     68.602430
# estado_civil                  1.097266
# edad                          0.000000
# institucion_derechohab        0.824060
# nivel_edu                     1.122809
# ocupacion                    16.173563
# religion                      6.581373
# parentesco                   58.454943
# entidad                       0.013327
# alc_o_municipio               7.181093
# edad_primera_menstruacion     3.541681
# edad_inicio_vida_sexual       4.433487
# fecha_ultima_menstruacion    14.132294
# semanas_embarazo              6.771285
# numero_hijos                 17.672864
# numero_embarazos              3.527243
# numero_abortos                5.668466
# numero_partos                 5.137602
# numero_cesareas               5.577397
# numero_iles                  15.109616
# ...
